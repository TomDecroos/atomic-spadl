# %%
# %load_ext autoreload
# %autoreload 2
import os; import sys; sys.path.insert(0,'../')
import warnings
import pandas as pd
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

import socceraction.spadl.api as spadl
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
optafolder = "../data/opta/"
jsonfiles = [os.path.join(optafolder,f) for f in os.listdir(optafolder) if ".json" in f]
jsonfiles
# Out:
# ['../data/opta/match-2017-9-917811.json']

# %%
#help(spadl.optajson_to_optah5)
import json
with open(jsonfiles[0]) as fh:
    print(jsonfiles[0])
    root = json.load(fh, encoding='utf-8')
root
# Out:
# ../data/opta/match-2017-9-917811.json
# [{'url': 'http://omo.akamai.opta.net/?feed_type=f9_packed&game_id=917811',
#   'data': {'bin_ver': 25,
#    'OptaFeed': {'@attributes': {'TimeStamp': '20170821T104309+0000',
#      'timestamp': {'locale': '2017-08-21T10:43:09.000Z',
#       'utc': '2017-08-21T10:43:09.000Z'}},
#     'OptaDocument': [{'@attributes': {'uID': 'g917811', 'Type': 'Result'},
#       'Competition': {'Stat': [{'@attributes': {'Type': 'season_id'},
#          '@value': 2017},
#         {'@attributes': {'Type': 'symid'}, '@value': 'NL_ED'},
#         {'@attributes': {'Type': 'matchday'}, '@value': 1}],
#        '@attributes': {'uID': 'c9'},
#        'Round': {'Name': '', 'RoundNumber': 0},
#        'compObj': {'type': 'COMP'}},
#       'MatchData': {'MatchInfo': {'Date': '20170811T170000+0000',
#         'dateObj': {'locale': '2017-08-11T17:00:00.000Z',
#          'utc': '2017-08-11T17:00:00.000Z'},
#         '@attributes': {'MatchType': 'Regular',
# ...

# %%
import socceraction.spadl.opta as opta
opta.extract_data(jsonfiles[0])
# Out:
# ../data/opta/match-2017-9-917811.json
# {'game': {'competition_id': 9,
#   'game_id': 917811,
#   'season_id': 2017,
#   'matchday': 1,
#   'home_team_id': 701,
#   'away_team_id': 325,
#   'venue_id': 7266,
#   'referee_id': 40229,
#   'game_date': Timestamp('2017-08-11 17:00:00+0000', tz='UTC'),
#   'attendance': 12134,
#   'duration': 93},
#  'players': [{'player_id': 15987,
#    'firstname': 'Robert',
#    'lastname': 'Zwinkels',
#    'fullname': 'Robert Zwinkels',
#    'knownname': 'Robert Zwinkels'},
#   {'player_id': 186703,
#    'firstname': 'Tyronne',
#    'lastname': 'Ebuehi',
#    'fullname': 'Tyronne Ebuehi',
#    'knownname': 'Tyronne Ebuehi'},
#   {'player_id': 52721,
#    'firstname': 'Aaron',
#    'lastname': 'Meijers',
#    'fullname': 'Aaron Meijers',
#    'knownname': 'Aaron Meijers'},
#   {'player_id': 86566,
#    'firstname': 'Tom',
#    'lastname': 'Beugelsdijk',
#    'fullname': 'Tom Beugelsdijk',
#    'knownname': 'Tom Beugelsdijk'},
#   {'player_id': 149426,
# ...

# %%
help(json.load)
# Out:
# Help on function load in module json:
#
# load(fp, *, cls=None, object_hook=None, parse_float=None, parse_int=None, parse_constant=None, object_pairs_hook=None, **kw)
#     Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     a JSON document) to a Python object.
#
#     ``object_hook`` is an optional function that will be called with the
#     result of any object literal decode (a ``dict``). The return value of
#     ``object_hook`` will be used instead of the ``dict``. This feature
#     can be used to implement custom decoders (e.g. JSON-RPC class hinting).
#
#     ``object_pairs_hook`` is an optional function that will be called with the
#     result of any object literal decoded with an ordered list of pairs.  The
#     return value of ``object_pairs_hook`` will be used instead of the ``dict``.
#     This feature can be used to implement custom decoders.  If ``object_hook``
#     is also defined, the ``object_pairs_hook`` takes priority.
#
# ...

# %%
optah5 =  os.path.join(optafolder,"opta.h5")
spadl.optajson_to_optah5(jsonfiles,optah5,False)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/software/miniconda3/envs/soccer/lib/python3.7/site-packages/pandas/io/pytables.py in _create_storer(self, group, format, value, append, **kwargs)
#    1411                 try:
# -> 1412                     pt = _TYPE_MAP[type(value)]
#    1413                 except KeyError:
#
# KeyError: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-7322bac15688> in <module>
#       1 optah5 =  os.path.join(optafolder,"opta.h5")
# ----> 2 spadl.optajson_to_optah5(jsonfiles,optah5,False)
#
# /export/home1/NoCsBack/dtai/tomd/atomic-spadl/socceraction/spadl/opta.py in jsonfiles_to_h5(jsonfiles, h5file, append)
# ...

# %%
spadlh5 = os.path.join(optafolder,"spadl.h5")
spadl.optah5_to_spadlh5(optah5,spadlh5)

# %%
import pandas as pd
pd.read_hdf(optah5,"players")
# Out:
#     player_id firstname         lastname                fullname  \
# 6      223181    Dennis  van der Heijden  Dennis van der Heijden
# 14     204649  Giovanni          Troupee        Giovanni Troupee
# 1      186703   Tyronne           Ebuehi          Tyronne Ebuehi
# 13     178494    Gyrano             Kerk             Gyrano Kerk
# 9      167145      Sean          Klaiber            Sean Klaiber
# 4      149426     Danny           Bakker            Danny Bakker
# 12     119440    Yassin            Ayoub            Yassin Ayoub
# 8       91691  Ludcinio          Marengo        Ludcinio Marengo
# 3       86566       Tom      Beugelsdijk         Tom Beugelsdijk
# 15      74315      Mark   van der Maarel     Mark van der Maarel
# 7       72157       Tim         Coremans            Tim Coremans
# 2       52721     Aaron          Meijers           Aaron Meijers
# 11      48733     Ramon          Leeuwin           Ramon Leeuwin
# ...
